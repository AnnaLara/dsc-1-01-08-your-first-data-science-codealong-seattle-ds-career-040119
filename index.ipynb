# %% [markdown]
# # Your First Data Science Codealong!
#
# ## Introduction
#
# In this codealong, you'll get to do your first taste of a real data science workflow! You'll use Jupyter Notebook to import pre-written libraries, import data into your notebook from a Comma Seperated Values file (a .csv file) and you'll even get to create some plots!
#
# Don't worry if it feels like a lot or you get confused on this codealogn. Our goal here is just to give you a taste of what you'll be able to do as a data scientist, and afterwards, we'll go back and re-introduce all of the concepts that we skimmed over this time through, so by the end of the section you should have a much stronger understanding of this - even if you have no previous experience of programming.
#
# Don't worry about running tests for this notebook. Just take your time to explore the data and the code.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Code along (following detailed instructions) to import a csv file and then plot the data

# %% [markdown]
# ## Jupyter Notebook and Running Cells
#
# **Welcome to programming!**
# Juptyer Notebooks (historically called IPythonNotebooks) will be our primary tool when conducting data science. The first thing to know with this is that each cell block [of code] can be run be pressing **shift+enter**. Try running the below code block:

# %%
print('This is code being run.')
# Out:
# This is code being run.

# %% [markdown]
# ## Importing Packages
# The next thing we're going to do is load in some python packages that will be part of our toolbox for manipulating and analyzing data. The standard python package for working with data tables is called **pandas**. Below, we import this under the **alias** pd, which is the industry standard. This will give us a shorthand way to access special functions and methods within the package without having to type the longer name pandas.
#
# * Again, press **shift+enter** to run the code below

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Jupyter Notebook Cell Types
#
# You might have started to notice that the code blocks have little notes that say **In [ ]:** before you run them, and then are filled with a number after you run them. This is important, as it tells you what order cell blocks were run. (Which can sometimes affect how a program runs.)
#
# You may also notice that other cell blocks, such as this one, do not have the **In [ ]:** label as with the code blocks. This is because this cell block is formatted as **Markdown** rather then code. You can see (and change) what type of cell is by clicking the dropdown menu at the top:
# <img src="Jupyter_Notebook_Cell_Type_Dropdown.png" width=600>

# %% [markdown]
# # Command Versus Edit Mode
#
# You should also start to notice that when you are in a cell writing code (or notes), the cell is highlighted in **green** meaning you are in **edit mode**.
#
# Alternatively, if you **press esc**, the cursor will be in **blue** inidicating that you are in **command mode**.
#
# ### Edit Mode
# Edit mode is the standard mode for editing cells, whether its writing code or notes.
# To enter edit mode from command mode simply hit enter, or double click on a cell.
#
# ### Command Mode
# In command mode, you can delete cells, add cells, copy cells, paste cells, change cell types, and more. You can also do these tasks in a more cumbersome (and time consuming) manner by using the various headers in the menu bar at top.
# <img src="Jupyter_Menu.png" width=600>
# You can also see a full list of shortcuts available in command and edit mode under the help menu.
#
# <img src="Jupyter_Help_Menu.png" width=600>

# %% [markdown]
# # Running Bash Commands
#
# We can also run bash commands just as we did before from the terminal directly within iPython notebooks!
#  (Note: bash commands cannot be mixed with python and must be in their own cell block.)
#
# Try it out!

# %%
pwd
# Out:
# '/home/annaz/dsc-1-01-08-your-first-data-science-codealong-seattle-ds-career-040119'

# %%
ls
# Out:
# CONTRIBUTING.md                          lego_sets.csv*
# docstring.png                            LICENSE.md
# docstring_preview.png                    pd_methods.png
# index_files/                             pd_read_methods.png
# index.ipynb                              python_built_in_functions.png
# Jupyter_Help_Menu.png                    README.md
# Jupyter_Menu.png                         string-slicing.png
# Jupyter_Notebook_Cell_Type_Dropdown.png

# %% [markdown]
# ## Loading a DataFrame
# The primary datatype within the pandas package is called a dataframe and is similar to a spreadsheet in excel. Here's a brief example of loading a csv file from your hard drive:

# %%
df = pd.read_csv('lego_sets.csv') #Loads the dataframe in
print(len(df)) #Prints the length of the dataframe
df.head() #Uses a built in method common to all Pandas Dataframes
# Out:
# 12261
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3  Discover the architectural secrets of the icon...           Average
# 4  Discover the architectural secrets of Frank Ll...       Challenging
#
#                          set_name  star_rating    theme_name  val_star_rating  \
# 0           Bird Island Egg Heist          4.5  Angry Birds™              4.0
# 1              Piggy Plane Attack          5.0  Angry Birds™              4.0
# 2                Piggy Car Escape          4.3  Angry Birds™              4.1
# 3  United States Capitol Building          4.6  Architecture              4.3
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture              4.1
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %% [markdown]
# # Python Comments
#
# Note the green text following the **#**.
# Anything following a **#** in python is a comment and will not actually execute.
# This is a useful feature for annotating your code with notes for yourself and other later so that your code is easy to read.

# %% [markdown]
# # Accessing Methods from Packages and Objects
#
# A little more theory and context:
#
# When we loaded in packages on our first cell block (import pandas as pd), we loaded code into memory. That code included functions, variables and other objects. Collectively, all of these items is loaded under the package name or alias.
#
# We demonstrated this when we used the **pd.read_csv()** method above.
#
# This also demonstrates the **dot notation** in python, which is how we access built in methods or attriubtes of a given object. Similar to what we saw with bash in the command line, we can also use **tab completion** to preview methods available in packages or other objects.
#
# ### Try this out yourself
#
# * In the cell below, navigate your cursor to the right of **pd.**
# * Press tab to see a list of available methods/attributes
#
# <img src="pd_methods.png" width=600>

# %%
pd.
# Out:
#   File "<ipython-input-11-bc888235687a>", line 1
#     pd.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# You can also start typing to subset the list of available commands:
# <img src="pd_read_methods.png" width=600>

# %% [markdown]
# # Pulling up Docstrings
#
# Even better, you can even see how a method works by pulling up its **docstring**!
# You can do this by writing **?** after the method and running the cell.
#
# <img src="docstring.png" width=500>
#
#
# Try it out!

# %%
pd.read_csv?

# %% [markdown]
# Alternatively, you can pull up a preview of the docstring by pressing **shift+tab within the parentheses of a method**
# <img src="docstring_preview.png" width=500>

# %%
pd.read_csv() #Move your cursor inside the parentheses and press shift+tab

# %% [markdown]
# # Variables
#
# The other thing that happened in our block of code above was that we defined a **variable**.
#
# This happened in the first line of code:
# ```df = pd.read_csv('lego_sets.csv')```
#
# As we saw, we used the built in *read_csv* method from the *pandas* package which we imported under the *alias* *pd*.
#
# The output of this method was then assigned to the variable *df*. This is the standard syntax for declaring any variable. You do not have to specify variable types, as in many other programming languages. Simply:
#
# `variable_name = what_to_stor_in_the_variable`

# %% [markdown]
# # Built in Python Functions
#
# We also used two built in python functions:
#     * len() #Returns the lenght of an object
#     * print() #Prints stuff!
# In general, **python has reserved keywords** for built in functions like this.
# **Be sure to not name your variables any of these!**
#
# <img src="python_built_in_functions.png" width=600>

# %% [markdown]
# You can also check what type of object something is using the built in **type()** method. This can be useful when determining how to work with an object that you are unfamiliar with.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Common DataFrame Methods
# As you can see, our variable **df** is a DataFrame object (which is part of the Pandas core package). Here's some other common methods you will want to become familiar with when working with Pandas dataframes:
# * df.head()
#     * Preview the first 5 rows of a dataframe. Pass a number for more/less rows
# * df.tail(10)
#     * Preview last 10 rows (default 5 if no number given)
# * df.info()
#     * Returns column names and details about each column
# * df.columns
#     * Return column names. Note that there is no parentheses for this. This is becuase this is an attribute as opposed to a method

# %%
#Practice using some of these methods
df.head(1)
df.tail(1)
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
# ages                 12261 non-null object
# list_price           12261 non-null float64
# num_reviews          10641 non-null float64
# piece_count          12261 non-null float64
# play_star_rating     10486 non-null float64
# prod_desc            11884 non-null object
# prod_id              12261 non-null float64
# prod_long_desc       12261 non-null object
# review_difficulty    10206 non-null object
# set_name             12261 non-null object
# star_rating          10641 non-null float64
# theme_name           12258 non-null object
# val_star_rating      10466 non-null float64
# country              12261 non-null object
# dtypes: float64(7), object(7)
# memory usage: 1.3+ MB
# Index(['ages', 'list_price', 'num_reviews', 'piece_count', 'play_star_rating',
#        'prod_desc', 'prod_id', 'prod_long_desc', 'review_difficulty',
#        'set_name', 'star_rating', 'theme_name', 'val_star_rating', 'country'],
#       dtype='object')

# %%
#Use tab completion to investigate at least 3 other methods under the df object. 
#Pull up their docstrings and investigate what they do.
df.abs
df.add_prefix('prefix')
df.drop_duplicates()
# Out:
#         ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0       6-12     29.9900          2.0        277.0               4.0
# 1       6-12     19.9900          2.0        168.0               4.0
# 2       6-12     12.9900         11.0         74.0               4.3
# 3        12+     99.9900         23.0       1032.0               3.6
# 4        12+     79.9900         14.0        744.0               3.2
# 5        12+     59.9900          7.0        597.0               3.7
# 6        12+     59.9900         37.0        598.0               3.7
# 7        12+     49.9900         24.0        780.0               4.4
# 8        12+     39.9900         23.0        468.0               3.6
# 9        12+     39.9900         11.0        444.0               3.6
# 10       12+     39.9900         14.0        386.0               4.1
# 11       12+     34.9900         53.0        321.0               3.2
# 12       12+     29.9900          7.0        361.0               4.2
# 13      7-12    159.9900         63.0        847.0               3.8
# 14       10+     29.9900         13.0        708.0               4.7
# 15       10+     19.9900          1.0        234.0               3.0
# 16       10+     19.9900          1.0        160.0               5.0
# 17       10+      9.9900          1.0        149.0               2.0
# 18       10+      9.9900          1.0        141.0               2.0
# 19       10+      9.9900          3.0        101.0               4.0
# 20       10+      9.9900          2.0        105.0               3.0
# 21       10+      9.9900          1.0        113.0               5.0
# 22       10+      9.9900          1.0        136.0               NaN
# 23       10+      9.9900          2.0         91.0               3.0
# 24       10+      9.9900          7.0        140.0               3.2
# 25       10+      9.9900          5.0        143.0               4.6
# 26       10+      9.9900          3.0        122.0               2.7
# 27       10+      9.9900          5.0        130.0               4.3
# 28       10+      9.9900          3.0        119.0               4.5
# 29       10+      9.9900          1.0        135.0               1.0
# ...      ...         ...          ...          ...               ...
# 12205  10-16    121.9878          8.0       1005.0               4.1
# 12206   9-16    109.7878         28.0        370.0               4.6
# 12207  10-16    109.7878         12.0       1098.0               4.0
# 12208   9-16     91.4878          5.0       1020.0               3.8
# 12209  10-16     67.0878         12.0        603.0               4.2
# 12210   8-14     67.0878          8.0        631.0               4.7
# 12211   9-16     54.8878          1.0        513.0               5.0
# 12212   9-16     43.9078         57.0         10.0               4.6
# 12213   8-14     36.5878          5.0        330.0               4.0
# 12214   7-14     24.3878          1.0        135.0               5.0
# 12215   7-14     24.3878          2.0        139.0               4.5
# 12216   7-14     24.3878          7.0        142.0               4.4
# 12217   8-14     24.3878         10.0        365.0               4.6
# 12218   7-14     24.3878          2.0        140.0               4.5
# 12219   8-14     20.7278          9.0        199.0               4.3
# 12220   8-14     18.2878          2.0        171.0               5.0
# 12221   7-14     13.4078          2.0        176.0               4.5
# 12223  12-16    207.3878         20.0       1628.0               3.5
# 12224  10-16    176.8878         18.0       1456.0               4.6
# 12225   8-14    140.2878         23.0       1047.0               4.7
# 12226   9-14    121.9878          4.0       1053.0               4.0
# 12227   8-14     79.2878         20.0        581.0               4.6
# 12228   8-14     69.5278         19.0        433.0               4.4
# 12230   8-14     60.9878          6.0        366.0               3.7
# 12233   8-14     42.6878         24.0        305.0               4.5
# 12234   7-14     42.6878         18.0        254.0               4.2
# 12236   7-14     30.4878          8.0        204.0               4.1
# 12237   7-14     30.4878         19.0        201.0               4.1
# 12238   6-12     18.2878          7.0        141.0               4.0
# 12239   6-12     18.2878         18.0        124.0               4.5
#
#                                                prod_desc  prod_id  \
# 0      Catapult into action and take back the eggs fr...  75823.0
# 1      Launch a flying attack and rescue the eggs fro...  75822.0
# 2      Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3      Explore the architecture of the United States ...  21030.0
# 4      Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
# 5      Celebrate Shanghai with this LEGO® Architectur...  21039.0
# 6      Celebrate New York City with this LEGO® Archit...  21028.0
# 7      Recreate Buckingham Palace with LEGO® Architec...  21029.0
# 8      Celebrate London with this LEGO® Architecture ...  21034.0
# 9      Celebrate Chicago with this LEGO® Architecture...  21033.0
# 10       Experience the grandeur of the Arc de Triomphe!  21036.0
# 11     Build your own LEGO® interpretation of the ico...  21019.0
# 12     Celebrate Sydney with this LEGO® Architecture ...  21032.0
# 13                   Bring your LEGO® creations to life!  17101.0
# 14         Build a LEGO® BrickHeadz version of yourself!  41597.0
# 15     Train a raptor with LEGO® BrickHeadz™ Owen and...  41614.0
# 16     Join Mr. Incredible and Frozone for LEGO® Bric...  41613.0
# 17     Growl like a Wookiee with a LEGO® BrickHeadz™ ...  41609.0
# 18     Be a rogue with a LEGO® BrickHeadz™ constructi...  41608.0
# 19     Save the universe with LEGO® BrickHeadz Iron M...  41604.0
# 20     Feel the power of Infinity with LEGO® BrickHea...  41605.0
# 21     Be a legendary outlaw with LEGO® BrickHeadz St...  41606.0
# 22     Master the skills of a green-skinned assassin ...  41607.0
# 23     Join the Resistance with a LEGO® BrickHeadz co...  41485.0
# 24     Say “I love you” with a LEGO® BrickHeadz™ Vale...  40270.0
# 25       Stand tall with LEGO® BrickHeadz Wonder Woman™!  41599.0
# 26     Live life in the fast lane with LEGO® BrickHea...  41598.0
# 27     Summon the dark side with a LEGO® BrickHeadz c...  41603.0
# 28     Feel the Force with a LEGO® BrickHeadz constru...  41602.0
# 29               Dive in with LEGO® BrickHeadz Aquaman™!  41600.0
# ...                                                  ...      ...
# 12205  Push the limits with the awesome LEGO® Technic...  42077.0
# 12206  Travel over the toughest terrain with the RC T...  42065.0
# 12207               Mobilize the Airport Rescue Vehicle!  42068.0
# 12208  Transport supplies over land and sea with the ...  42076.0
# 12209            Experience the BMW R 1200 GS Adventure!  42063.0
# 12210  Grab, lift, load and deliver at the Container ...  42062.0
# 12211  Explore iconic vehicle design with the First R...  42075.0
# 12212  Motorize your LEGO® Technic creations with the...   8293.0
# 12213  Put the wind in your sails with this amazing R...  42074.0
# 12214  Get ready for high-speed action and impacts wi...  42072.0
# 12215  Get ready for high-speed action and impacts wi...  42073.0
# 12216  Fly off the ramp at high speed with the super-...  42059.0
# 12217                         Call in the Roadwork Crew!  42060.0
# 12218  Hit the ramp at high speed with the awesome St...  42058.0
# 12219  Take to the skies with the Ultralight Helicopter!  42057.0
# 12220              Call in the powerful Dozer Compactor!  42071.0
# 12221  Collect and transport heavy cargo with the Hoo...  42084.0
# 12223             Break into Arkham Asylum with Batman™!  70912.0
# 12224  Divide the 4-in-1 Ultimate Batmobile and conqu...  70917.0
# 12225   Protect the Batcave from The Penguin’s invasion!  70909.0
# 12226   Patrol the sky above Gotham City in The Batwing!  70916.0
# 12227  Pursue Man-Bat™ and the Kabuki Twins™ in the B...  70905.0
# 12228  Team up with Batgirl™ to stop The Joker’s Noto...  70906.0
# 12230     Protect Gotham City from Bane’s toxic attacks!  70914.0
# 12233  Put the heat on The Penguin™ Arctic Roller wit...  70911.0
# 12234  Battle with Batman™ against The Riddler™ and h...  70903.0
# 12236  Help Batman™ to stop Scarecrow™ delivering a s...  70910.0
# 12237  Protect the power plant from Mr. Freeze’s ice ...  70901.0
# 12238  Power into the sky to stop Scarecrow’s fear ga...  70913.0
# 12239             Help Batman™ stop The Joker™ escaping!  70900.0
#
#                                           prod_long_desc review_difficulty  \
# 0      Use the staircase catapult to launch Red into ...           Average
# 1      Pilot Pig has taken off from Bird Island with ...              Easy
# 2      Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3      Discover the architectural secrets of the icon...           Average
# 4      Discover the architectural secrets of Frank Ll...       Challenging
# 5      Recreate Shanghai in China's blend of historic...           Average
# 6      Celebrate the architectural diversity of New Y...           Average
# 7      Build a LEGO® brick model of London's official...           Average
# 8      Celebrate the architectural diversity of Londo...           Average
# 9      Recreate Chicago’s blend of historical and mod...           Average
# 10     Capture the architectural elegance of one of t...           Average
# 11     Presenting the LEGO® Architecture interpretati...           Average
# 12     Capture the architectural essence and splendor...              Easy
# 13     Take your LEGO® play to the next level with th...           Average
# 14     Fuel your creativity by making a LEGO® BrickHe...           Average
# 15     These LEGO® BrickHeadz™ 41614 Owen & Blue cons...              Easy
# 16     These LEGO® BrickHeadz™ 41613 Mr. Incredible &...         Very Easy
# 17     This LEGO® BrickHeadz™ 41609 Chewbacca is fun ...         Very Easy
# 18     This LEGO® BrickHeadz™ 41608 Han Solo is fun t...         Very Easy
# 19     This Iron Man MK50 LEGO® BrickHeadz constructi...           Average
# 20     This Thanos LEGO® BrickHeadz construction char...              Easy
# 21     This Star-Lord LEGO® BrickHeadz construction c...              Easy
# 22     This Gamora LEGO® BrickHeadz construction char...               NaN
# 23     This LEGO® BrickHeadz construction character f...              Easy
# 24     Build your way to someone’s heart and say “Bee...              Easy
# 25     This Wonder Woman™ LEGO® BrickHeadz constructi...              Easy
# 26     The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 27     This LEGO® BrickHeadz construction character f...              Easy
# 28     This LEGO® BrickHeadz construction character f...              Easy
# 29     This Aquaman™ LEGO® BrickHeadz construction ch...         Very Easy
# ...                                                  ...               ...
# 12205  Discover awesome detail and design with this a...           Average
# 12206  Spin, turn, clamber over obstacles and race at...              Easy
# 12207  Head for the runway with this authentic 2-in-1...           Average
# 12208  Reach inhospitable areas with the LEGO® Techni...           Average
# 12209  Explore the high-tech innovation of the BMW R ...           Average
# 12210  Enjoy a rewarding build-and-play experience wi...              Easy
# 12211  Enjoy a rewarding build and play experience wi...              Easy
# 12212  Bring your LEGO® Technic models to life with t...              Easy
# 12213  Enter the world of water sports with this amaz...           Average
# 12214  Experience the amazing power and acceleration ...               NaN
# 12215  Experience the amazing power and acceleration ...              Easy
# 12216  Perform amazing stunts with this high-speed LE...              Easy
# 12217  Get to work with this exciting, two-vehicle LE...              Easy
# 12218  Perform impressive stunts with this high-speed...              Easy
# 12219  Enjoy aerial adventures with this aerodynamic ...              Easy
# 12220  Capture the awesome power of a real-life dozer...       Challenging
# 12221  Enjoy a rewarding build-and-play experience wi...              Easy
# 12223  Bust into Arkham Asylum with Batman™ and banis...           Average
# 12224  Team up with THE LEGO® BATMAN MOVIE characters...           Average
# 12225  Defend against The Penguin’s Duckmobile invasi...           Average
# 12226  Fly high above Gotham City in the Batwing and ...           Average
# 12227  Race through Gotham City in pursuit of Man-Bat...           Average
# 12228  Join Batgirl’s pursuit of The Joker™ and Harle...           Average
# 12230  Stop Bane™ and Mutant Leader’s toxic attacks w...           Average
# 12233  Join Batman’s pursuit of The Penguin in THE LE...              Easy
# 12234  Take on four Super-Villains at once in THE LEG...              Easy
# 12236  Save Gotham City Energy Facility from a fear g...           Average
# 12237  Help Batman™ defend the Gotham City Energy Fac...              Easy
# 12238  Team up with Batman™ to stop Scarecrow™ spread...              Easy
# 12239  Stage a face-off between The Joker™ and Batman...              Easy
#
#                              set_name  star_rating              theme_name  \
# 0               Bird Island Egg Heist          4.5            Angry Birds™
# 1                  Piggy Plane Attack          5.0            Angry Birds™
# 2                    Piggy Car Escape          4.3            Angry Birds™
# 3      United States Capitol Building          4.6            Architecture
# 4       Solomon R. Guggenheim Museum®          4.6            Architecture
# 5                            Shanghai          4.9            Architecture
# 6                       New York City          4.2            Architecture
# 7                   Buckingham Palace          4.7            Architecture
# 8                              London          4.7            Architecture
# 9                             Chicago          4.8            Architecture
# 10                    Arc de Triomphe          4.4            Architecture
# 11                   The Eiffel Tower          4.6            Architecture
# 12                             Sydney          4.6            Architecture
# 13             BOOST Creative Toolbox          3.4                   BOOST
# 14                        Go Brick Me          4.8              BrickHeadz
# 15                        Owen & Blue          5.0              BrickHeadz
# 16           Mr. Incredible & Frozone          5.0              BrickHeadz
# 17                         Chewbacca™          3.0              BrickHeadz
# 18                          Han Solo™          4.0              BrickHeadz
# 19                      Iron Man MK50          4.7              BrickHeadz
# 20                             Thanos          5.0              BrickHeadz
# 21                          Star-Lord          5.0              BrickHeadz
# 22                             Gamora          5.0              BrickHeadz
# 23                               Finn          4.5              BrickHeadz
# 24                    Valentine's Bee          4.9              BrickHeadz
# 25                      Wonder Woman™          5.0              BrickHeadz
# 26                         The Flash™          4.0              BrickHeadz
# 27                          Kylo Ren™          5.0              BrickHeadz
# 28                                Rey          5.0              BrickHeadz
# 29                           Aquaman™          4.0              BrickHeadz
# ...                               ...          ...                     ...
# 12205                       Rally Car          4.4                 Technic
# 12206                RC Tracked Racer          4.5                 Technic
# 12207          Airport Rescue Vehicle          4.8                 Technic
# 12208                      Hovercraft          4.2                 Technic
# 12209         BMW R 1200 GS Adventure          4.7                 Technic
# 12210                  Container Yard          4.8                 Technic
# 12211                 First Responder          5.0                 Technic
# 12212       Power Functions Motor Set          4.5         Power Functions
# 12213                    Racing Yacht          4.8                 Technic
# 12214                          WHACK!          5.0                 Technic
# 12215                           BASH!          4.0                 Technic
# 12216                     Stunt Truck          4.7                 Technic
# 12217                   Roadwork Crew          4.8                 Technic
# 12218                      Stunt Bike          4.0                 Technic
# 12219           Ultralight Helicopter          4.7                 Technic
# 12220                 Dozer Compactor          5.0                 Technic
# 12221                     Hook Loader          4.5                 Technic
# 12223                   Arkham Asylum          3.8  THE LEGO® BATMAN MOVIE
# 12224          The Ultimate Batmobile          4.6  THE LEGO® BATMAN MOVIE
# 12225                Batcave Break-in          4.7  THE LEGO® BATMAN MOVIE
# 12226                     The Batwing          4.0  THE LEGO® BATMAN MOVIE
# 12227                   The Batmobile          4.8  THE LEGO® BATMAN MOVIE
# 12228   The Joker™ Notorious Lowrider          4.7  THE LEGO® BATMAN MOVIE
# 12230        Bane™ Toxic Truck Attack          4.0  THE LEGO® BATMAN MOVIE
# 12233      The Penguin™ Arctic Roller          4.8  THE LEGO® BATMAN MOVIE
# 12234       The Riddler™ Riddle Racer          4.2  THE LEGO® BATMAN MOVIE
# 12236     Scarecrow™ Special Delivery          4.4  THE LEGO® BATMAN MOVIE
# 12237          Mr. Freeze™ Ice Attack          4.6  THE LEGO® BATMAN MOVIE
# 12238     Scarecrow™ Fearful Face-off          4.1  THE LEGO® BATMAN MOVIE
# 12239       The Joker™ Balloon Escape          4.7  THE LEGO® BATMAN MOVIE
#
#        val_star_rating country
# 0                  4.0      US
# 1                  4.0      US
# 2                  4.1      US
# 3                  4.3      US
# 4                  4.1      US
# 5                  4.4      US
# 6                  4.1      US
# 7                  4.3      US
# 8                  4.1      US
# 9                  4.5      US
# 10                 3.6      US
# 11                 4.4      US
# 12                 4.2      US
# 13                 3.5      US
# 14                 4.8      US
# 15                 5.0      US
# 16                 5.0      US
# 17                 4.0      US
# 18                 4.0      US
# 19                 4.5      US
# 20                 5.0      US
# 21                 5.0      US
# 22                 NaN      US
# 23                 4.0      US
# 24                 4.7      US
# 25                 5.0      US
# 26                 3.0      US
# 27                 4.8      US
# 28                 4.5      US
# 29                 3.0      US
# ...                ...     ...
# 12205              4.1      PT
# 12206              4.2      PT
# 12207              4.6      PT
# 12208              4.2      PT
# 12209              4.4      PT
# 12210              4.3      PT
# 12211              4.0      PT
# 12212              3.9      PT
# 12213              4.2      PT
# 12214              5.0      PT
# 12215              3.5      PT
# 12216              4.6      PT
# 12217              4.6      PT
# 12218              4.0      PT
# 12219              4.8      PT
# 12220              5.0      PT
# 12221              4.5      PT
# 12223              3.3      PT
# 12224              4.6      PT
# 12225              4.3      PT
# 12226              3.8      PT
# 12227              4.3      PT
# 12228              4.2      PT
# 12230              3.0      PT
# 12233              4.4      PT
# 12234              4.4      PT
# 12236              4.1      PT
# 12237              4.4      PT
# 12238              4.4      PT
# 12239              4.6      PT
#
# [10872 rows x 14 columns]

# %% [markdown]
# # Pandas Series
#
# While the entire spreadsheet is called a **dataframe**, each individual column is known as a **series**. You can access a specific column of a pandas dataframe one of two ways:
#
# `df['col_name']`
#
# or
#
# ```df.col_name```
#
# First note that in `df['col_name']` we need 'quotations' around the column name. The quotations denote the column name is a **string**, python's built in variable type for storing text. This can alternatively be replaced with double quotes `df["col_name"]`. In general, anything in quotations is a string in python code. Occassionally, with very ill formatted column names with quotations in the names themselves, you may even need to wrap a name in triple quotes `df["""col_name"""]` . This will rarely happen in this particular context, but is also the general pattern for dealing with messy strings.
#
# Note that the second method, `df.col_name`, will only work if there are no spaces within the name of the column. Similarly to tab completion with the command line, this is a primary reason why programers use dashes (-) and underscores (_) in lieu of whitespace in their variable and file names. Also note that no quotations are used when using this format. (The column names have been stored as attributes to the DataFrame object!)

# %%
#Previewing Data

# %%
df.head(2) #preview your spreadsheet again; 2 keeps it a nice small preview
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
#
#                 set_name  star_rating    theme_name  val_star_rating country
# 0  Bird Island Egg Heist          4.5  Angry Birds™              4.0      US
# 1     Piggy Plane Attack          5.0  Angry Birds™              4.0      US

# %%
df.ages.head()
# Out:
# 0    6-12
# 1    6-12
# 2    6-12
# 3     12+
# 4     12+
# Name: ages, dtype: object

# %%
df.ages[:5] #Here we introduce another new syntax the list slice [:5] this limits us to the first 5 items
# Out:
# 0    6-12
# 1    6-12
# 2    6-12
# 3     12+
# 4     12+
# Name: ages, dtype: object

# %% [markdown]
# # List and Series Slices
# Above, we introduced an entirely new programming pattern called a slice.
# The syntax for a slice is `[start:end]`.
#
# You can also pass an additional third parameter `[start:end:count_by]` which will allow you to:
# count every other: `[start:end:2]`
# count backwards: `start:end:-1]`
# or potentially much more cryptic patterns, depending on what you pass.
#
# While we could have also used `df.State.head()`, slicing works for many more datatypes. This includes the previously mentioned *strings* as well as **lists** and other iterable objects. **Series**, the columns of the pandas DataFrame are similar to python's built in *lists*, but also have additional *methods* built in to them that we will continue to investigate.

# %%
df.piece_count
# Out:
# 0         277.0
# 1         168.0
# 2          74.0
# 3        1032.0
# 4         744.0
# 5         597.0
# 6         598.0
# 7         780.0
# 8         468.0
# 9         444.0
# 10        386.0
# 11        321.0
# 12        361.0
# 13        847.0
# 14        708.0
# 15        234.0
# 16        160.0
# 17        149.0
# 18        141.0
# 19        101.0
# 20        105.0
# 21        113.0
# 22        136.0
# 23         91.0
# 24        140.0
# 25        143.0
# 26        122.0
# 27        130.0
# 28        119.0
# 29        135.0
#           ...
# 12231     267.0
# 12232     293.0
# 12233     305.0
# 12234     254.0
# 12235     198.0
# 12236     204.0
# 12237     201.0
# 12238     141.0
# 12239     124.0
# 12240       8.0
# 12241     643.0
# 12242    4867.0
# 12243    2295.0
# 12244    1403.0
# 12245     830.0
# 12246    1202.0
# 12247     914.0
# 12248     944.0
# 12249     876.0
# 12250     747.0
# 12251     521.0
# 12252     544.0
# 12253     494.0
# 12254     312.0
# 12255     341.0
# 12256     341.0
# 12257     217.0
# 12258     233.0
# 12259      48.0
# 12260     109.0
# Name: piece_count, Length: 12261, dtype: float64

# %% [markdown]
# # Common Series Methods
# Some very useful series methods include:
# * df.col_name.value_counts()
# * df.col_name.astype()
# * series.mean()     #Changing notation here: series refers to df.col_name (which is a series)!
# * series.median()
# * series.min()
# * series.max()
# * series.std()
# * series.unique()
# * series.nunique()
# * series.sample()
# * series.sort_values()
#
# There are also many more but this is a very good starting point.
# Start pulling up some docstrings and getting acquainted with reading them yourself before we go through a few of these methods together.

# %%
df.play_star_rating.value_counts #Read the docstring and tinker! See how it works.
# Out:
# <bound method IndexOpsMixin.value_counts of 0        4.0
# 1        4.0
# 2        4.3
# 3        3.6
# 4        3.2
# 5        3.7
# 6        3.7
# 7        4.4
# 8        3.6
# 9        3.6
# 10       4.1
# 11       3.2
# 12       4.2
# 13       3.8
# 14       4.7
# 15       3.0
# 16       5.0
# 17       2.0
# 18       2.0
# 19       4.0
# 20       3.0
# 21       5.0
# 22       NaN
# 23       3.0
# 24       3.2
# 25       4.6
# 26       2.7
# 27       4.3
# 28       4.5
# 29       1.0
#         ...
# 12231    3.6
# 12232    4.9
# 12233    4.5
# 12234    4.2
# 12235    4.0
# 12236    4.1
# 12237    4.1
# 12238    4.0
# 12239    4.5
# 12240    4.3
# 12241    4.4
# 12242    4.8
# 12243    4.7
# 12244    4.5
# 12245    4.6
# 12246    4.7
# 12247    4.8
# 12248    3.6
# 12249    4.7
# 12250    4.3
# 12251    4.7
# 12252    4.6
# 12253    4.6
# 12254    3.5
# 12255    4.2
# 12256    4.4
# 12257    4.1
# 12258    4.6
# 12259    5.0
# 12260    4.5
# Name: play_star_rating, Length: 12261, dtype: float64>

# %%
#Keep tinkering!

# %% [markdown]
# # Graphing
#
# Our bread and butter tool for graphing in python will be **matplotlib**.
# There are a number of other packages you can also check out for visualization later on such as plotly, folium, and bokeh to name a few, but matplotlib is an industry standard used widely. As with the pandas package, we must import  the matplotlib package to use its built in functions and methods. Rather then import the entire package however, we import only the piece we intend to use (hence the dot notation) and again alias this under the shorthand *plt*. Finally, the iPython magic command **% matplotlib inline** makes these graphs appear within our jupyter notebook.

# %%
#import a subset of the matplotlib package under the alias 'plt'
import matplotlib.pyplot as plt

#ipython magic command for displaying graphs within the notebook
# %matplotlib inline

# %%
to_graph = df.theme_name.value_counts()[:5]
to_graph.plot(kind='barh')

# %% [markdown]
# # Adding labels
# The graph above is a good start, but we should be sure to add some labels! To do this we make successive calls to the `plt` package we imported. Some common methods you should be familiar with include:
# * plt.title()
# * plt.xlabel()
# * plt.ylabel()
# * plt.legend()
# * plt.xticks()
# * plt.yticks()

# %%
to_graph = df.theme_name.value_counts()[:5]
to_graph.plot(kind='barh') #lots of other optional parameters can be passed such as color
plt.title('Top 5 Lego Themes', fontsize=16) #fontsize is optional
plt.xlabel('Number of Lego Sets') #you could also pass in fontsize if you wanted here
plt.ylabel('Theme') #you could also rotate text if you wanted
# Out:
# Text(0,0.5,'Theme')

# %% [markdown]
# # Practice and Explore
#
# Take a minute to try chaining some of these methods together to create a few of your own visuals for practice. Some ideas can include making a scatter plot with `plt.scatter(x , y)` where you pass in two series (one as x and the other as y), plotting histograms with the `series.hist()` method, or creating simple bar graphs as shown above.

# %%
plt.scatter(df.play_star_rating, df.star_rating)

# %%
df.play_star_rating.hist()

# %%
#Your code here
plt.plot(df.play_star_rating, df.star_rating)
